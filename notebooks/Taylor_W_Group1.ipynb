# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### Chicago crews able to fill more potholes due to warmer weather
#
# 1. Go to the Chicago Data Portal: https://data.cityofchicago.org/
# 2. Find each dataset. pothole requests and potholes patched.
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %% [markdown]
# My own work for the project -
# Work day 4/15

# %%
pothole = pd.read_csv("https://data.cityofchicago.org/resource/7as2-ds3y.csv?$limit=1000000")

# %%
patched = pd.read_csv("https://data.cityofchicago.org/resource/wqdh-9gek.csv?$limit=1000000")

# %%
pothole.head(20)
# Out:
#               creation_date      status completion_date  \
# 0   2018-12-18T00:00:00.000        Open             NaN
# 1   2018-12-18T00:00:00.000        Open             NaN
# 2   2018-12-18T00:00:00.000        Open             NaN
# 3   2018-12-18T00:00:00.000  Open - Dup             NaN
# 4   2018-12-18T00:00:00.000        Open             NaN
# 5   2018-12-18T00:00:00.000        Open             NaN
# 6   2018-12-18T00:00:00.000        Open             NaN
# 7   2018-12-18T00:00:00.000        Open             NaN
# 8   2018-12-18T00:00:00.000        Open             NaN
# 9   2018-12-18T00:00:00.000        Open             NaN
# 10  2018-12-18T00:00:00.000        Open             NaN
# 11  2018-12-18T00:00:00.000  Open - Dup             NaN
# 12  2018-12-18T00:00:00.000        Open             NaN
# 13  2018-12-18T00:00:00.000        Open             NaN
# 14  2018-12-18T00:00:00.000        Open             NaN
# 15  2018-12-18T00:00:00.000        Open             NaN
# ...

# %%
pothole.tail()
# Out:
#                   creation_date     status          completion_date  \
# 560473  2010-03-11T00:00:00.000  Completed  2011-03-28T00:00:00.000
# 560474  2010-02-26T00:00:00.000  Completed  2011-10-04T00:00:00.000
# 560475  2009-08-27T00:00:00.000  Completed  2011-01-25T00:00:00.000
# 560476  2009-06-17T00:00:00.000  Completed  2011-06-07T00:00:00.000
# 560477  2009-01-12T00:00:00.000  Completed  2011-10-06T00:00:00.000
#
#        service_request_number type_of_service_request current_activity  \
# 560473            10-00317212      Pot Hole in Street    Dispatch Crew
# 560474            10-00254019      Pot Hole in Street              NaN
# 560475            09-01501980      Pot Hole in Street      Site Survey
# 560476            09-01026546      Pot Hole in Street    Dispatch Crew
# 560477            09-00061329      Pot Hole in Street    Dispatch Crew
#
#        most_recent_action  number_of_potholes_filled_on_block  \
# 560473    Pothole Patched                                 5.0
# ...

# %%
pothole.columns
# Out:
# Index(['creation_date', 'status', 'completion_date', 'service_request_number',
#        'type_of_service_request', 'current_activity', 'most_recent_action',
#        'number_of_potholes_filled_on_block', 'street_address', 'zip',
#        'x_coordinate', 'y_coordinate', 'ward', 'police_district',
#        'community_area', 'ssa', 'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
pothole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560478 entries, 0 to 560477
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   creation_date                       560478 non-null  object
#  1   status                              560478 non-null  object
#  2   completion_date                     553130 non-null  object
#  3   service_request_number              560478 non-null  object
#  4   type_of_service_request             560478 non-null  object
#  5   current_activity                    393609 non-null  object
#  6   most_recent_action                  391992 non-null  object
#  7   number_of_potholes_filled_on_block  399143 non-null  float64
#  8   street_address                      560476 non-null  object
#  9   zip                                 558160 non-null  float64
#  10  x_coordinate                        560004 non-null  float64
# ...

# %%
pothole.shape
# Out:
# (560478, 19)

# %%
print(pothole)
# Out:
#                   creation_date      status          completion_date  \
# 0       2018-12-18T00:00:00.000        Open                      NaN
# 1       2018-12-18T00:00:00.000        Open                      NaN
# 2       2018-12-18T00:00:00.000        Open                      NaN
# 3       2018-12-18T00:00:00.000  Open - Dup                      NaN
# 4       2018-12-18T00:00:00.000        Open                      NaN
# ...                         ...         ...                      ...
# 560473  2010-03-11T00:00:00.000   Completed  2011-03-28T00:00:00.000
# 560474  2010-02-26T00:00:00.000   Completed  2011-10-04T00:00:00.000
# 560475  2009-08-27T00:00:00.000   Completed  2011-01-25T00:00:00.000
# 560476  2009-06-17T00:00:00.000   Completed  2011-06-07T00:00:00.000
# 560477  2009-01-12T00:00:00.000   Completed  2011-10-06T00:00:00.000
#
#        service_request_number type_of_service_request current_activity  \
# ...

# %%
patched.head()
# Out:
#                  address             request_date          completion_date  \
# 0     4809 N ROCKWELL ST  2024-04-16T10:07:46.000  2024-04-16T15:19:59.000
# 1  1158 W WRIGHTWOOD AVE  2024-04-16T15:16:13.000  2024-04-16T15:18:40.000
# 2      5822 N TALMAN AVE  2024-04-15T14:09:05.000  2024-04-16T15:10:56.000
# 3      5905 N TALMAN AVE  2024-04-15T14:07:36.000  2024-04-16T15:10:08.000
# 4   5734 N FAIRFIELD AVE  2024-04-15T14:00:20.000  2024-04-16T15:09:03.000
#
#    number_of_potholes_filled_on_block   latitude  longitude  \
# 0                                   8  41.968881 -87.693633
# 1                                  68  41.929110 -87.658429
# 2                                   6  41.987484 -87.695915
# 3                                   9  41.988834 -87.695442
# 4                                  14  41.985981 -87.698322
#
#                                    location
# 0  POINT (-87.693633000002 41.968881000941)
# 1  POINT (-87.658429500002 41.929110000941)
# ...

# %%
patched.tail()
# Out:
#                     address             request_date          completion_date  \
# 179953       3911 W 61ST ST  2019-02-13T09:14:18.000  2019-02-28T07:14:27.000
# 179954       3908 W 61ST ST  2019-02-13T09:11:06.000  2019-02-28T07:13:30.000
# 179955       3900 W 62ND PL  2019-02-13T09:19:31.000  2019-02-28T07:12:22.000
# 179956       3847 W 61ST PL  2019-02-13T18:50:19.000  2019-02-28T07:11:16.000
# 179957  6400 S MAJOR Avenue  2018-08-01T15:13:33.000  2019-01-09T11:36:02.000
#
#         number_of_potholes_filled_on_block   latitude  longitude  \
# 179953                                   4  41.782065 -87.720834
# 179954                                   3  41.782588 -87.720808
# 179955                                  10  41.779863 -87.720513
# 179956                                  15  41.781169 -87.719803
# 179957                                  16  41.776112 -87.764137
#
#                                         location
# 179953              POINT (-87.720834 41.782065)
# ...

# %%
patched.columns
# Out:
# Index(['address', 'request_date', 'completion_date',
#        'number_of_potholes_filled_on_block', 'latitude', 'longitude',
#        'location'],
#       dtype='object')

# %%
patched.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179958 entries, 0 to 179957
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   address                             179958 non-null  object
#  1   request_date                        179958 non-null  object
#  2   completion_date                     179958 non-null  object
#  3   number_of_potholes_filled_on_block  179958 non-null  int64
#  4   latitude                            179489 non-null  float64
#  5   longitude                           179489 non-null  float64
#  6   location                            179489 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 9.6+ MB

# %%
patched.shape
# Out:
# (179958, 7)

# %%
print(patched)
# Out:
#                       address             request_date  \
# 0          4809 N ROCKWELL ST  2024-04-16T10:07:46.000
# 1       1158 W WRIGHTWOOD AVE  2024-04-16T15:16:13.000
# 2           5822 N TALMAN AVE  2024-04-15T14:09:05.000
# 3           5905 N TALMAN AVE  2024-04-15T14:07:36.000
# 4        5734 N FAIRFIELD AVE  2024-04-15T14:00:20.000
# ...                       ...                      ...
# 179953         3911 W 61ST ST  2019-02-13T09:14:18.000
# 179954         3908 W 61ST ST  2019-02-13T09:11:06.000
# 179955         3900 W 62ND PL  2019-02-13T09:19:31.000
# 179956         3847 W 61ST PL  2019-02-13T18:50:19.000
# 179957    6400 S MAJOR Avenue  2018-08-01T15:13:33.000
#
#                 completion_date  number_of_potholes_filled_on_block  \
# 0       2024-04-16T15:19:59.000                                   8
# 1       2024-04-16T15:18:40.000                                  68
# 2       2024-04-16T15:10:56.000                                   6
# ...

# %% [markdown]
# Project work in group - Work Day 4/16

# %% [markdown]
# Must convert data types at least once
#  pd.to_numeric()
# pd.to_datetime()

# %%
patched['request_date'] = pd.to_datetime(patched['request_date'])

# %%
patched['Year'] = patched['request_date'].dt.year

# %%
patched['Month'] = patched['request_date'].dt.year

# %%
patched['Weekday'] = patched['request_date'].dt.year

# %%
patched['Day'] = patched['request_date'].dt.year

# %%
patched['Hour'] = patched['request_date'].dt.year

# %%
patched['Minute'] = patched['request_date'].dt.year

# %%
patched.columns
# Out:
# Index(['address', 'request_date', 'completion_date',
#        'number_of_potholes_filled_on_block', 'latitude', 'longitude',
#        'location', 'Year', 'Month', 'Weekday', 'Day', 'Hour', 'Minute'],
#       dtype='object')

# %% [markdown]
# Work Day 4/17

# %% [markdown]
# Must use at least three groupbys()
# Use at least two: mean(), median, sum(), min(), max(), count(), size(), first(), last()

# %%
patched.groupby('number_of_potholes_filled_on_block').size().sort_values(ascending = False)
# Out:
# number_of_potholes_filled_on_block
# 1      20562
# 2      18070
# 3      14262
# 5      12535
# 4      12006
#        ...
# 212        1
# 214        1
# 215        1
# 218        1
# 467        1
# Length: 230, dtype: int64

# %%
pothole.groupby('ward')['type_of_service_request'].count().sort_values(ascending = False)
# Out:
# ward
# 41.0    21637
# 45.0    16788
# 19.0    16534
# 23.0    16398
# 32.0    16173
# 13.0    15765
# 39.0    15699
# 8.0     15336
# 42.0    14730
# 34.0    14528
# 21.0    14126
# 2.0     13790
# 18.0    13761
# 36.0    13687
# 27.0    13221
# 38.0    12878
# 50.0    12760
# 14.0    12244
# 10.0    12146
# 40.0    11965
# 29.0    11730
# 6.0     11460
# 35.0    10732
# 28.0    10693
# 25.0    10621
# 1.0     10545
# 5.0     10438
# 9.0     10380
# 11.0     9743
# 12.0     9620
# 49.0     9551
# 47.0     9458
# 31.0     9351
# 17.0     9055
# 24.0     9044
# 37.0     8942
# 30.0     8436
# 26.0     8358
# 43.0     8231
# 7.0      7997
# 33.0     7922
# 16.0     7825
# 3.0      7611
# 20.0     7541
# 15.0     7334
# 48.0     7076
# 4.0      7042
# 22.0     6966
# 44.0     6373
# 46.0     4340
# 0.0      1564
# Name: type_of_service_request, dtype: int64

# %% [markdown]
# Must use at least one conditional logic
# If/else
#  np.where()
# np.select()

# %%
duplicates = pothole.duplicated()

# %%
num_duplicates = duplicates.sum()

# %%
if num_duplicates > 0:
  print(f'there are {num_duplicates} duplicate rows in the dataset.')
else:
  print('there are no duplicate rows in the dataet.')
# Out:
# there are 2 duplicate rows in the dataset.

# %%
#string.split with street name to see which has the most

# %%
pothole['street_address'].unique()
# Out:
# array(['1145 S FAIRFIELD AVE', '908 S CAMPBELL AVE', '2421 W 21ST PL',
#        ..., '1599 N ELK GROVE AVE', '801 W 111TH ST',
#        '1440 S ROCKWELL ST'], dtype=object)

# %%
pothole['street_address'].str.split()
# Out:
# 0         [1145, S, FAIRFIELD, AVE]
# 1           [908, S, CAMPBELL, AVE]
# 2               [2421, W, 21ST, PL]
# 3               [1959, S, TROY, ST]
# 4          [4100, S, WESTERN, BLVD]
#                     ...
# 560473      [7201, W, BELMONT, AVE]
# 560474      [1440, S, ROCKWELL, ST]
# 560475        [5518, N, WAYNE, AVE]
# 560476       [3845, W, ADDISON, ST]
# 560477       [2519, S, HALSTED, ST]
# Name: street_address, Length: 560478, dtype: object

# %%
pothole['street_address'].value_counts().reset_index()
# Out:
#                  street_address  count
# 0             55 W JACKSON BLVD    386
# 1            1800 S WESTERN AVE    316
# 2          8300 S VINCENNES AVE    313
# 3       7500 S STONY ISLAND AVE    274
# 4       9500 S STONY ISLAND AVE    268
# ...                         ...    ...
# 250602         3420 W NORTH AVE      1
# 250603      2754 W ROOSEVELT RD      1
# 250604      3932 W LAWRENCE AVE      1
# 250605           138 E 123RD ST      1
# 250606       1440 S ROCKWELL ST      1
#
# [250607 rows x 2 columns]

# %%
duplicates_mask = pothole.duplicated(subset = 'service_request_number', keep=False)

# %%
pothole['is_duplicated'] = duplicates_mask

# %%
pothole.head()
# Out:
#              creation_date      status completion_date service_request_number  \
# 0  2018-12-18T00:00:00.000        Open             NaN            18-03387505
# 1  2018-12-18T00:00:00.000        Open             NaN            18-03387458
# 2  2018-12-18T00:00:00.000        Open             NaN            18-03387502
# 3  2018-12-18T00:00:00.000  Open - Dup             NaN            18-03388379
# 4  2018-12-18T00:00:00.000        Open             NaN            18-03388180
#
#   type_of_service_request current_activity most_recent_action  \
# 0       Pothole in Street              NaN                NaN
# 1       Pothole in Street              NaN                NaN
# 2       Pothole in Street              NaN                NaN
# 3       Pothole in Street              NaN                NaN
# 4       Pothole in Street              NaN                NaN
#
#    number_of_potholes_filled_on_block        street_address      zip  \
# ...

# %% [markdown]
# Did this even drop or point out the duplicated rows?

# %%
status_dup = pothole['status'].duplicated()

# %%
duplicate_rows = pothole[status_dup]

# %%
print(duplicate_rows)
# Out:
#                   creation_date     status          completion_date  \
# 1       2018-12-18T00:00:00.000       Open                      NaN
# 2       2018-12-18T00:00:00.000       Open                      NaN
# 4       2018-12-18T00:00:00.000       Open                      NaN
# 5       2018-12-18T00:00:00.000       Open                      NaN
# 6       2018-12-18T00:00:00.000       Open                      NaN
# ...                         ...        ...                      ...
# 560473  2010-03-11T00:00:00.000  Completed  2011-03-28T00:00:00.000
# 560474  2010-02-26T00:00:00.000  Completed  2011-10-04T00:00:00.000
# 560475  2009-08-27T00:00:00.000  Completed  2011-01-25T00:00:00.000
# 560476  2009-06-17T00:00:00.000  Completed  2011-06-07T00:00:00.000
# 560477  2009-01-12T00:00:00.000  Completed  2011-10-06T00:00:00.000
#
#        service_request_number type_of_service_request current_activity  \
# 1                 18-03387458       Pothole in Street              NaN
# ...

# %%
pothole_no_status_dup = pothole.drop_duplicates()

# %%
pothole_no_status_dup.reset_index()
# Out:
#          index            creation_date      status          completion_date  \
# 0            0  2018-12-18T00:00:00.000        Open                      NaN
# 1            1  2018-12-18T00:00:00.000        Open                      NaN
# 2            2  2018-12-18T00:00:00.000        Open                      NaN
# 3            3  2018-12-18T00:00:00.000  Open - Dup                      NaN
# 4            4  2018-12-18T00:00:00.000        Open                      NaN
# ...        ...                      ...         ...                      ...
# 560471  560473  2010-03-11T00:00:00.000   Completed  2011-03-28T00:00:00.000
# 560472  560474  2010-02-26T00:00:00.000   Completed  2011-10-04T00:00:00.000
# 560473  560475  2009-08-27T00:00:00.000   Completed  2011-01-25T00:00:00.000
# 560474  560476  2009-06-17T00:00:00.000   Completed  2011-06-07T00:00:00.000
# 560475  560477  2009-01-12T00:00:00.000   Completed  2011-10-06T00:00:00.000
#
# ...
